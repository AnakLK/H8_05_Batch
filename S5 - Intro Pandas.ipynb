# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\Hacktiv8'

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('NBA.csv')

# %%
len(df)
# Out:
# 2899

# %%
df.shape
# Out:
# (100, 23)

# %%
df.head
# Out:
# <bound method NDFrame.head of     gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947   11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947   11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947   11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947   11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947   11/2/1946           1
# ..        ...           ...   ...      ...      ...         ...         ...
# 95         48  194611240CLR   NBA        0     1947  11/24/1946           7
# 96         49  194611250BOS   NBA        1     1947  11/25/1946          10
# 97         49  194611250BOS   NBA        0     1947  11/25/1946          10
# 98         50  194611250PIT   NBA        1     1947  11/25/1946           9
# 99         50  194611250PIT   NBA        0     1947  11/25/1946          10
#
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
pd.set_option("display.precision", 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameorder      100 non-null    int64
#  1   game_id        100 non-null    object
#  2   lg_id          100 non-null    object
#  3   _iscopy        100 non-null    int64
#  4   year_id        100 non-null    int64
#  5   date_game      100 non-null    object
#  6   seasongame     100 non-null    int64
#  7   is_playoffs    100 non-null    int64
#  8   team_id        100 non-null    object
#  9   fran_id        100 non-null    object
#  10  pts            100 non-null    int64
#  11  elo_i          100 non-null    float64
#  12  elo_n          100 non-null    float64
#  13  win_equiv      100 non-null    float64
#  14  opp_id         100 non-null    object
#  15  opp_fran       100 non-null    object
#  16  opp_pts        100 non-null    int64
# ...

# %%
df.describe()
# Out:
#        gameorder     _iscopy  year_id  seasongame  is_playoffs         pts  \
# count  100.00000  100.000000    100.0  100.000000        100.0  100.000000
# mean    25.50000    0.500000   1947.0    5.240000          0.0   64.200000
# std     14.50357    0.502519      0.0    2.860811          0.0   10.485199
# min      1.00000    0.000000   1947.0    1.000000          0.0   33.000000
# 25%     13.00000    0.000000   1947.0    3.000000          0.0   56.000000
# 50%     25.50000    0.500000   1947.0    5.000000          0.0   65.000000
# 75%     38.00000    1.000000   1947.0    8.000000          0.0   71.000000
# max     50.00000    1.000000   1947.0   11.000000          0.0   92.000000
#
#              elo_i        elo_n   win_equiv     opp_pts    opp_elo_i  \
# count   100.000000   100.000000  100.000000  100.000000   100.000000
# mean   1299.193003  1299.193001   40.915955   64.200000  1299.193003
# std      19.999684    22.925247    2.397475   10.485199    19.999684
# ...

# %%
df["team_id"].value_counts()
# Out:
# CHS    11
# TRH    10
# DTF    10
# BOS    10
# PRO    10
# PIT    10
# STB    10
# NYK     9
# WSC     9
# CLR     7
# PHW     4
# Name: team_id, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# Stags           11
# Huskies         10
# Falcons         10
# Celtics         10
# Steamrollers    10
# Ironmen         10
# Bombers         10
# Knicks           9
# Capitols         9
# Rebels           7
# Warriors         4
# Name: fran_id, dtype: int64

# %%
df.loc[df["fran_id"] == "Warriors", "team_id"].value_counts()
# Out:
# PHW    4
# Name: team_id, dtype: int64

# %%
df.loc[df["team_id"] == "CHS", "date_game"].min()
# Out:
# '11/11/1946'

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.index
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
city_revenues = pd.Series(
        [4200, 8000, 6500], 
        index= ["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes[0] #index baris
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1] #index kolom
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_revenues[1]
# Out:
# 8000

# %%
city_revenues[-1]
# Out:
# 6500

# %%
city_revenues[1:]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
city_revenues["Toronto":]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
colors = pd.Series(
    ["red", "yellow", "green", "purple", "blue"], 
    index=[1, 3, 5, 7, 9]
)

colors
# Out:
# 1       red
# 3    yellow
# 5     green
# 7    purple
# 9      blue
# dtype: object

# %%
colors.loc[1] #loc = akses index yang dibuat / explicit idx
# Out:
# 'red'

# %%
colors.iloc[1] #iloc = akses index bawaan py / implicit idx
# Out:
# 'yellow'

# %%
colors.loc[1:7]
# Out:
# 1       red
# 3    yellow
# 5     green
# 7    purple
# dtype: object

# %%
colors.iloc[0:3]
# Out:
# 1       red
# 3    yellow
# 5     green
# dtype: object

# %%
city_data["revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
"""
Series = kumpulan data berisi nilai dan index explisit
DataFrame = kumpulan series berisi kumpulan series
(idx = nama series)

# %%
city_data.loc["Tokyo"]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
city_data.loc["Tokyo": "Toronto"]
# Out:
#          revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
city_data.iloc[0]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
df.iloc[-2]
# Out:
# gameorder                  50
# game_id          194611250PIT
# lg_id                     NBA
# _iscopy                     1
# year_id                  1947
# date_game          11/25/1946
# seasongame                  9
# is_playoffs                 0
# team_id                   NYK
# fran_id                Knicks
# pts                        62
# elo_i               1309.9252
# elo_n               1327.9469
# win_equiv           43.926521
# opp_id                    PIT
# opp_fran              Ironmen
# opp_pts                    46
# opp_elo_i           1282.9152
# opp_elo_n           1264.8934
# game_location               A
# game_result                 W
# forecast             0.396477
# notes                     NaN
# Name: 98, dtype: object

# %%
df.loc[15:40, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#          fran_id      opp_fran  pts  opp_pts
# 15         Stags       Celtics   57       55
# 16       Bombers       Falcons   53       49
# 17       Falcons       Bombers   49       53
# 18       Ironmen      Warriors   75       81
# 19      Warriors       Ironmen   81       75
# 20  Steamrollers         Stags   73       65
# 21         Stags  Steamrollers   65       73
# 22       Bombers        Knicks   63       68
# 23        Knicks       Bombers   68       63
# 24       Huskies       Falcons   73       71
# 25       Falcons       Huskies   71       73
# 26       Huskies         Stags   54       62
# 27         Stags       Huskies   62       54
# 28       Celtics       Falcons   46       69
# 29       Falcons       Celtics   69       46
# 30  Steamrollers       Ironmen   76       66
# 31       Ironmen  Steamrollers   66       76
# 32       Bombers      Capitols   70       69
# 33      Capitols       Bombers   69       70
# 34        Rebels      Capitols   92       68
# ...

# %%
current_decade = df[df["year_id"] < 1948]
current_decade
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947   11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947   11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947   11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947   11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947   11/2/1946           1
# ..        ...           ...   ...      ...      ...         ...         ...
# 95         48  194611240CLR   NBA        0     1947  11/24/1946           7
# 96         49  194611250BOS   NBA        1     1947  11/25/1946          10
# 97         49  194611250BOS   NBA        0     1947  11/25/1946          10
# 98         50  194611250PIT   NBA        1     1947  11/25/1946           9
# 99         50  194611250PIT   NBA        0     1947  11/25/1946          10
#
# ...

# %%
games_with_notes = df[df["notes"].notnull()]
games_with_notes.shape
# Out:
# (132, 23)

# %%
ers = df[df["fran_id"].str.endswith("ers")]
ers.shape
# Out:
# (663, 23)

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("PRO")) &
    (df["year_id"] == 1947)
]
# Out:
#      gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 7            4  194611020PRO   NBA        0     1947   11/2/1946           1
# 20          11  194611070PRO   NBA        0     1947   11/7/1946           2
# 30          16  194611090PRO   NBA        0     1947   11/9/1946           3
# 57          29  194611160PRO   NBA        0     1947  11/16/1946           7
# 81          41  194611210PRO   NBA        0     1947  11/21/1946           8
# 88          45  194611230PRO   NBA        0     1947  11/23/1946           9
# 111        107  194612190PRO   NBA        0     1947  12/19/1946          18
# 115        109  194612210PRO   NBA        0     1947  12/21/1946          19
# 129        116  194612260PRO   NBA        0     1947  12/26/1946          20
# 138        120  194612280PRO   NBA        0     1947  12/28/1946          21
# 170        136  194701040PRO   NBA        0     1947    1/4/1947          23
# ...

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.max()
# Out:
# 8000

# %%
points = df["pts"]

# %%
points.sum()
# Out:
# 221894

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
#
# [3 rows x 23 columns]

# %%
df.groupby("fran_id", sort=False)["pts"].sum()
# Out:
# fran_id
# Huskies          3482
# Knicks          18191
# Stags           19438
# Falcons          3109
# Capitols        18717
# Celtics         16612
# Steamrollers    11897
# Ironmen          3122
# Bombers         17179
# Rebels           3742
# Warriors        18836
# Baltimore       14670
# Jets             4482
# Pistons          9702
# Lakers          11495
# Kings           10840
# Hawks            5236
# Denver           4818
# Olympians        5495
# Redskins         5108
# Waterloo         4842
# Packers          5522
# Sixers           5359
# Name: pts, dtype: int64

# %%
df[
    (df["fran_id"] == "Celtics") &
    (df["year_id"] > 1940)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 1947     L              33
#          W              18
# 1948     L              30
#          W              21
# 1949     L              35
#          W              25
# 1950     L              46
#          W              22
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 1948)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              21
#              W              27
# 1            L               7
#              W               6
# Name: game_id, dtype: int64

# %%
nba = df.copy()

# %%
nba.shape
# Out:
# (2899, 23)

# %%
nba["difference"] = df.pts - df.opp_pts
nba
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0             1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1             1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2             2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3             2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4             3  194611020DTF   NBA        0     1947  11/2/1946           1
# ...         ...           ...   ...      ...      ...        ...         ...
# 2894       1498  195003180DNN   NBA        0     1950  3/18/1950          62
# 2895       1499  195003180ROC   NBA        1     1950  3/18/1950          68
# 2896       1499  195003180ROC   NBA        0     1950  3/18/1950          67
# 2897       1500  195003180TRI   NBA        1     1950  3/18/1950          63
# 2898       1500  195003180TRI   NBA        0     1950  3/18/1950          63
#
# ...

# %%
nba["difference"].max()
# Out:
# 43

# %%
renamed_nba = nba.rename(
    columns ={"game_result": "result", "game_location": "location"}
)

renamed_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68  1300.0000
# 1            0     NYK   Knicks  ...     TRH   Huskies       66  1300.0000
# 2            0     CHS    Stags  ...     NYK    Knicks       47  1306.7233
# 3            0     NYK   Knicks  ...     CHS     Stags       63  1300.0000
# 4            0     DTF  Falcons  ...     WSC  Capitols       50  1300.0000
#
#    opp_elo_n location  result  forecast  notes difference
# ...

# %%
elo_columns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]

# %%
nba.drop(elo_columns, inplace=True, axis=1)

# %%
nba.shape
# Out:
# (2899, 20)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2899 entries, 0 to 2898
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameorder      2899 non-null   int64
#  1   game_id        2899 non-null   object
#  2   lg_id          2899 non-null   object
#  3   _iscopy        2899 non-null   int64
#  4   year_id        2899 non-null   int64
#  5   date_game      2899 non-null   object
#  6   seasongame     2899 non-null   int64
#  7   is_playoffs    2899 non-null   int64
#  8   team_id        2899 non-null   object
#  9   fran_id        2899 non-null   object
#  10  pts            2899 non-null   int64
#  11  win_equiv      2899 non-null   float64
#  12  opp_id         2899 non-null   object
#  13  opp_fran       2899 non-null   object
#  14  opp_pts        2899 non-null   int64
#  15  game_location  2899 non-null   category
#  16  game_result    2899 non-null   object
# ...

# %%
nba["data_game"] = pd.to_datetime(nba["date_game"])

# %%
nba["game_location"] = pd.Categorical(nba["game_location"])

# %%
nba["game_location"].dtype
# Out:
# CategoricalDtype(categories=['A', 'H'], ordered=False)

# %%
#rows_without_missing_data = nba.dropna()
rows_without_missing_data.shape
# Out:
# (132, 21)

# %%
#data_without_missing_columns = nba.dropna(axis= 1)
data_without_missing_columns.shape
# Out:
# (2899, 20)

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"]
)

# %%
all_city_data = pd.concat([city_data, further_city_data], sort=False)
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
countries = pd.DataFrame({
    "population_millions": [17, 127, 37],
    "continent": ["Europe", "Asia", "North America"]
}, index=["Holland", "Japan", "Canada"])

# %%
pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(
    cities,
    countries,
    left_on="country", 
    right_index=True,
    how="left"
)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %%
nba
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0             1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1             1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2             2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3             2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4             3  194611020DTF   NBA        0     1947  11/2/1946           1
# ...         ...           ...   ...      ...      ...        ...         ...
# 2894       1498  195003180DNN   NBA        0     1950  3/18/1950          62
# 2895       1499  195003180ROC   NBA        1     1950  3/18/1950          68
# 2896       1499  195003180ROC   NBA        0     1950  3/18/1950          67
# 2897       1500  195003180TRI   NBA        1     1950  3/18/1950          63
# 2898       1500  195003180TRI   NBA        0     1950  3/18/1950          63
#
# ...

# %%
# %matplotlib inline
nba[nba["fran_id"] == "Celtics"].groupby("year_id")["pts"].sum().plot()
# Out:
# <Axes: xlabel='year_id'>

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
nba["fran_id"].value_counts().head(10)
# Out:
# Warriors        251
# Stags           247
# Capitols        245
# Knicks          241
# Bombers         239
# Celtics         230
# Baltimore       190
# Steamrollers    161
# Lakers          137
# Kings           131
# Name: fran_id, dtype: int64
